# %% [markdown]
# ---
# This notebook will take an image of a hand of cards and it will identify individual cards.
#
# ---

# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt


image = cv2.imread('irl-dealt-hand-images/dealt-hand-1.png')
image = cv2.cvtColor(image, cv2.cv.CV_BGR2RGB)

plt.figure(figsize=(15,15))
_ = plt.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-6b4ce460e855> in <module>()
#       5
#       6 image = cv2.imread('irl-dealt-hand-images/dealt-hand-1.png')
# ----> 7 image = cv2.cvtColor(image, cv2.cv.CV_BGR2RGB)
#       8
#       9 plt.figure(figsize=(15,15))
#
# error: /tmp/opencv20160107-29960-t5glvv/opencv-2.4.12/modules/imgproc/src/color.cpp:3650: error: (-215) scn == 3 || scn == 4 in function cvtColor

# %%
import numpy as np


gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (1,1), 1000)
flag, thresh = cv2.threshold(blur, 120, 255, cv2.THRESH_BINARY)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
cv2.drawContours(image, contours, -1, (0, 255, 0), 3)

plt.figure(figsize=(15,15))
_ = plt.imshow(image)
